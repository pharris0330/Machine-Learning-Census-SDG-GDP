# %%
import pandas as pd

# %%
s_2019 = pd.read_csv('../Data/2019_Sdata_state.csv')

# %%
b_2019 = pd.read_csv('../Data/2019_Bdata_state.csv')

# %%
gdp_2019 = pd.read_csv('../Data/gdp_2019.csv')

# %%
df_2019 = s_2019.merge(b_2019, on='msa', how='left')

# %%
df_2019.columns
# Out:
# Index(['Unnamed: 0_x', 'NAME_x', 'S1701_C01_001E', 'S1703_C01_001E',
#        'S2201_C01_001E', 'S0101_C01_024E', 'S0101_C01_022E', 'S0101_C01_028E',
#        'S0101_C02_032E', 'S2301_C01_001E', 'msa', 'Unnamed: 0_y', 'NAME_y',
#        'B01001_001E', 'B25001_001E', 'B25002_001E', 'B25004_001E',
#        'B25005_001E', 'B25048_001E', 'B25052_001E', 'B25006_001E',
#        'B25007_012E', 'B25041_003E', 'B25041_004E', 'B25041_005E',
#        'B25041_006E', 'B25041_007E', 'B25019_001E', 'B06011_001E',
#        'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E',
#        'B06009_006E'],
#       dtype='object')

# %%
df_2019['_merge'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '_merge'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-6b1fbf300e0b> in <module>
# ----> 1 df_2019['_merge'].value_counts()
# ...

# %%
df_2019['msa'].value_counts()
# Out:
# 35840    1
# 12940    1
# 31900    1
# 11100    1
# 33780    1
#         ..
# 14020    1
# 25260    1
# 27980    1
# 24580    1
# 29620    1
# Name: msa, Length: 392, dtype: int64

# %%
len(df_2019)
# Out:
# 392

# %%
#rename msa column
df_2019.rename({'metropolitan statistical area/micropolitan statistical area': 'msa'}, axis=1,inplace=True)

# %%
df_2019 = df_2019.merge(gdp_2019, on='msa', how='left', indicator=True)
df_2019.columns
# Out:
# Index(['Unnamed: 0_x', 'NAME_x', 'S1701_C01_001E', 'S1703_C01_001E',
#        'S2201_C01_001E', 'S0101_C01_024E', 'S0101_C01_022E', 'S0101_C01_028E',
#        'S0101_C02_032E', 'S2301_C01_001E', 'msa', 'Unnamed: 0_y', 'NAME_y',
#        'B01001_001E', 'B25001_001E', 'B25002_001E', 'B25004_001E',
#        'B25005_001E', 'B25048_001E', 'B25052_001E', 'B25006_001E',
#        'B25007_012E', 'B25041_003E', 'B25041_004E', 'B25041_005E',
#        'B25041_006E', 'B25041_007E', 'B25019_001E', 'B06011_001E',
#        'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E',
#        'B06009_006E', '2019', '_merge'],
#       dtype='object')

# %%
# left_df.merge(right_df.rename({'user_id': 'user_id_r'}, axis=1),
#                left_on='user_id', right_on='user_id_r', how='left')

# %%
df_2019['_merge'].value_counts()
# Out:
# both          384
# left_only       8
# right_only      0
# Name: _merge, dtype: int64

# %%
left_only =  df_2019['_merge'] == 'left_only'
df_2019[left_only][0:3]
# Out:
#      Unnamed: 0_x                            NAME_x  S1701_C01_001E  \
# 1               4  Aguadilla-Isabela, PR Metro Area          287060
# 16             21            Arecibo, PR Metro Area          173625
# 147           184            Guayama, PR Metro Area           67227
#
#      S1703_C01_001E  S2201_C01_001E  S0101_C01_024E  S0101_C01_022E  \
# 1               NaN          101568          108116           49513
# 16              NaN           65208           64615           31364
# 147             NaN           24247           25910           12272
#
#      S0101_C01_028E  S0101_C02_032E  S2301_C01_001E  ...  B25041_007E  \
# 1             82805      -888888888          246271  ...         2337
# 16            49293      -888888888          147997  ...          838
# 147           19762      -888888888      -999999999  ...         1096
#
#      B25019_001E B06011_001E  B06009_002E  B06009_003E  B06009_004E  \
# ...

# %%
both =  df_2019['_merge'] == 'both'
df_2019 = df_2019[both]

# %%
df_2019
# Out:
#      Unnamed: 0_x                                        NAME_x  \
# 0               2                        Abilene, TX Metro Area
# 2               5                          Akron, OH Metro Area
# 3               7                         Albany, GA Metro Area
# 4               8                 Albany-Lebanon, OR Metro Area
# 5               9        Albany-Schenectady-Troy, NY Metro Area
# ..            ...                                           ...
# 386           512                         Yakima, WA Metro Area
# 388           514                   York-Hanover, PA Metro Area
# 389           515  Youngstown-Warren-Boardman, OH-PA Metro Area
# 390           516                      Yuba City, CA Metro Area
# 391           517                           Yuma, AZ Metro Area
#
#      S1701_C01_001E  S1703_C01_001E  S2201_C01_001E  S0101_C01_024E  \
# 0            158400             NaN           61750           75856
# ...

# %%
#rename msa column
df_2019.rename({'2019': 'gdp_2019','NAME_x': 'NAME'}, axis=1,inplace=True)

# %%
df_2019.columns
# Out:
# Index(['Unnamed: 0_x', 'NAME', 'S1701_C01_001E', 'S1703_C01_001E',
#        'S2201_C01_001E', 'S0101_C01_024E', 'S0101_C01_022E', 'S0101_C01_028E',
#        'S0101_C02_032E', 'S2301_C01_001E', 'msa', 'Unnamed: 0_y', 'NAME_y',
#        'B01001_001E', 'B25001_001E', 'B25002_001E', 'B25004_001E',
#        'B25005_001E', 'B25048_001E', 'B25052_001E', 'B25006_001E',
#        'B25007_012E', 'B25041_003E', 'B25041_004E', 'B25041_005E',
#        'B25041_006E', 'B25041_007E', 'B25019_001E', 'B06011_001E',
#        'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E',
#        'B06009_006E', 'gdp_2019', '_merge'],
#       dtype='object')

# %%
df_2019 = df_2019[['msa', 'NAME', 'S1701_C01_001E',
       'S2201_C01_001E', 'S0101_C01_024E', 'S0101_C01_022E', 'S0101_C01_028E', 'S2301_C01_001E', 
       'B01001_001E', 'B25001_001E', 'B25002_001E',
       'B25005_001E', 'B25048_001E', 'B25052_001E',
       'B25007_012E', 'B25041_003E', 'B25041_004E', 'B25041_005E',
       'B25041_006E', 'B25041_007E', 'B25019_001E', 'B06011_001E',
       'B06009_002E', 'B06009_003E', 'B06009_004E', 'B06009_005E',
       'B06009_006E', 'gdp_2019']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-598ff351227c> in <module>
# ----> 1 df_2019 = df_2019[['msa', 'NAME', 'S1701_C01_001E',
#       2        'S2201_C01_001E', 'S0101_C01_024E', 'S0101_C01_022E', 'S0101_C01_028E', 'S2301_C01_001E',
#       3        'B01001_001E', 'B25001_001E', 'B25002_001E', 'B25004_001E',
#       4        'B25005_001E', 'B25048_001E', 'B25052_001E',
#       5        'B25007_012E', 'B25041_003E', 'B25041_004E', 'B25041_005E',
#
# ~\Anaconda\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ...

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 384 entries, 0 to 391
# Data columns (total 29 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   msa             384 non-null    int64
#  1   NAME            384 non-null    object
#  2   S1701_C01_001E  384 non-null    int64
#  3   S2201_C01_001E  384 non-null    int64
#  4   S0101_C01_024E  384 non-null    int64
#  5   S0101_C01_022E  384 non-null    int64
#  6   S0101_C01_028E  384 non-null    int64
#  7   S2301_C01_001E  384 non-null    int64
#  8   B01001_001E     384 non-null    int64
#  9   B25001_001E     384 non-null    int64
#  10  B25002_001E     384 non-null    int64
#  11  B25004_001E     321 non-null    float64
#  12  B25005_001E     368 non-null    float64
#  13  B25048_001E     382 non-null    float64
#  14  B25052_001E     383 non-null    float64
#  15  B25007_012E     384 non-null    int64
#  16  B25041_003E     384 non-null    int64
# ...

# %%
df_2019.describe()
# Out:
#                 msa  S1701_C01_001E  S2201_C01_001E  S0101_C01_024E  \
# count    384.000000    3.840000e+02    3.840000e+02    3.840000e+02
# mean   29740.911458    7.198713e+05    2.733916e+05    2.968965e+05
# std    11392.733012    1.607849e+06    5.907092e+05    6.685021e+05
# min    10180.000000    5.363200e+04    2.270300e+04    2.020300e+04
# 25%    19770.000000    1.390910e+05    5.495700e+04    5.627500e+04
# 50%    29440.000000    2.389950e+05    9.524450e+04    1.003320e+05
# 75%    39760.000000    5.767900e+05    2.299208e+05    2.342782e+05
# max    49740.000000    1.887713e+07    7.102817e+06    7.670576e+06
#
#        S0101_C01_022E  S0101_C01_028E  S2301_C01_001E   B01001_001E  \
# count    3.840000e+02    3.840000e+02    3.840000e+02  3.840000e+02
# mean     1.644743e+05    1.631463e+05   -7.222515e+06  7.365262e+05
# std      3.631537e+05    3.485038e+05    8.821947e+07  1.635008e+06
# min      9.100000e+03    1.215600e+04   -1.000000e+09  5.591600e+04
# ...

# %%
#s2301 has -999999 minimum?

# %%
S1703_C01_001E  108 non-null    float64 (poverty)
B25004_001E     321 non-null    float64 (Vacancy status)
B25005_001E     368 non-null    float64 (Vacancy current owner elsewhere)
B25048_001E     382 non-null    float64 (plumbing facilities)
B25052_001E     383 non-null    float64 (kitchen facilities)
B06011_001E     383 non-null    float64 (median income)

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
na = df_2019['B25004_001E'].isna()

# %%
df_2019[na]
# Out:
#        msa                                     NAME  S1701_C01_001E  \
# 11   11180                      Ames, IA Metro Area          111389
# 14   11500           Anniston-Oxford, AL Metro Area          110599
# 28   12620                    Bangor, ME Metro Area          144971
# 33   13380                Bellingham, WA Metro Area          223451
# 34   13460                      Bend, OR Metro Area          195748
# 35   13740                  Billings, MT Metro Area          177540
# 57   16940                  Cheyenne, WY Metro Area           96763
# 59   16020         Cape Girardeau, MO-IL Metro Area           89888
# 61   16180               Carson City, NV Metro Area           53632
# 62   16220                    Casper, WY Metro Area           78004
# 74   17420                 Cleveland, TN Metro Area          122511
# 79   17860                  Columbia, MO Metro Area          197230
# 82   18020                  Columbus, IN Metro Area           82540
# ...

# %%
na = df_2019['B25005_001E'].isna()
df_2019[~na]
# Out:
#        msa                                          NAME  S1701_C01_001E  \
# 0    10180                        Abilene, TX Metro Area          158400
# 2    10420                          Akron, OH Metro Area          685097
# 3    10500                         Albany, GA Metro Area          141957
# 5    10580        Albany-Schenectady-Troy, NY Metro Area          850456
# 6    10740                    Albuquerque, NM Metro Area          902139
# ..     ...                                           ...             ...
# 386  49420                         Yakima, WA Metro Area          247015
# 388  49620                   York-Hanover, PA Metro Area          438490
# 389  49660  Youngstown-Warren-Boardman, OH-PA Metro Area          518600
# 390  49700                      Yuba City, CA Metro Area          172818
# 391  49740                           Yuma, AZ Metro Area          207253
#
#      S2201_C01_001E  S0101_C01_024E  S0101_C01_022E  S0101_C01_028E  \
# ...

# %%
x=df_2019['B25005_001E'].mean()
df_2019['B25005_001E']=df_2019['B25005_001E'].fillna(x)
# Out:
# <ipython-input-65-71efc48f35f7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['B25005_001E']=df_2019['B25005_001E'].fillna(x)

# %%
w=df_2019['B25048_001E'].mean()
df_2019['B25048_001E']=df_2019['B25048_001E'].fillna(w)

y=df_2019['B25052_001E'].mean()
df_2019['B25052_001E']=df_2019['B25052_001E'].fillna(y)

z=df_2019['B06011_001E'].mean()
df_2019['B06011_001E']=df_2019['B06011_001E'].fillna(z)
# Out:
# <ipython-input-67-e3190d724e71>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['B25048_001E']=df_2019['B25048_001E'].fillna(w)
# <ipython-input-67-e3190d724e71>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2019['B25052_001E']=df_2019['B25052_001E'].fillna(y)
# <ipython-input-67-e3190d724e71>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 384 entries, 0 to 391
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   msa             384 non-null    int64
#  1   NAME            384 non-null    object
#  2   S1701_C01_001E  384 non-null    int64
#  3   S2201_C01_001E  384 non-null    int64
#  4   S0101_C01_024E  384 non-null    int64
#  5   S0101_C01_022E  384 non-null    int64
#  6   S0101_C01_028E  384 non-null    int64
#  7   S2301_C01_001E  384 non-null    int64
#  8   B01001_001E     384 non-null    int64
#  9   B25001_001E     384 non-null    int64
#  10  B25002_001E     384 non-null    int64
#  11  B25005_001E     384 non-null    float64
#  12  B25048_001E     384 non-null    float64
#  13  B25052_001E     384 non-null    float64
#  14  B25007_012E     384 non-null    int64
#  15  B25041_003E     384 non-null    int64
#  16  B25041_004E     384 non-null    int64
# ...

# %%
df_2019.to_csv('../Data/2019_data.csv')
